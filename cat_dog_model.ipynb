# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
import matplotlib.pyplot as plt

# Définir les chemins des dossiers de formation et de test
base_dir = '../dogs_vs_cats'  # Remplacez par le chemin de votre dossier
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')  # Ajoutez un dossier de test si nécessaire

# Créer des sous-dossiers pour les images de chats et de chiens
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Générateur de données pour les images de formation et de test
train_datagen = ImageDataGenerator(rescale=1.0/255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)

# Construire un modèle de classification simple
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entraîner le modèle
model.fit(
    train_generator,
    steps_per_epoch=200,  # Nombre de lots par époque (à ajuster en fonction de la taille des données)
    epochs=200,            # Nombre d'époques d'entraînement
    validation_data=test_generator,
    validation_steps=50   # Nombre de lots de validation par époque
)

# Évaluer le modèle sur les données de test
test_loss, test_accuracy = model.evaluate(test_generator, steps=50)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")


# Afficher quelques images de test avec leurs étiquettes prédites
test_images, test_labels = next(test_generator)
predictions = model.predict(test_images)

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
for i, ax in enumerate(axes.flat):
    if i < len(test_images):
        ax.imshow(test_images[i])
        true_label = "Chat" if test_labels[i] == 0 else "Chien"
        predicted_label = "Chien" if predictions[i] > 0.5 else "Chat"
        ax.set_title(f"Vrai: {true_label}, Prédit: {predicted_label}")
        ax.axis('off')
plt.tight_layout()
plt.show()

# Sauvegarder le modèle entraîné
model.save('cat_dog_model.h5')
print("Model saved as cat_dog_model.h5")
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 196ms/step - accuracy: 0.5155 - loss: 0.8626 - val_accuracy: 0.6350 - val_loss: 0.6597
# Epoch 2/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 213ms/step - accuracy: 0.6383 - loss: 0.6479 - val_accuracy: 0.6240 - val_loss: 0.6610
# Epoch 3/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 219ms/step - accuracy: 0.6530 - loss: 0.6164 - val_accuracy: 0.6970 - val_loss: 0.5636
# Epoch 4/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 187ms/step - accuracy: 0.7004 - loss: 0.5807 - val_accuracy: 0.7500 - val_loss: 0.5247
# Epoch 5/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.7241 - loss: 0.5544 - val_accuracy: 0.7780 - val_loss: 0.5028
# Epoch 6/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 286ms/step - accuracy: 0.7172 - loss: 0.5506 - val_accuracy: 0.7520 - val_loss: 0.5085
# Epoch 8/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 272ms/step - accuracy: 0.7343 - loss: 0.5157 - val_accuracy: 0.7760 - val_loss: 0.4756
# Epoch 9/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 269ms/step - accuracy: 0.7649 - loss: 0.4886 - val_accuracy: 0.8000 - val_loss: 0.4472
# Epoch 10/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.7611 - loss: 0.4950 - val_accuracy: 0.7670 - val_loss: 0.5080
# Epoch 11/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 242ms/step - accuracy: 0.7698 - loss: 0.4750 - val_accuracy: 0.7350 - val_loss: 0.5318
# Epoch 12/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 286ms/step - accuracy: 0.7740 - loss: 0.4643 - val_accuracy: 0.7840 - val_loss: 0.4729
# Epoch 14/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 240ms/step - accuracy: 0.7817 - loss: 0.4549 - val_accuracy: 0.7910 - val_loss: 0.4504
# Epoch 15/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 234ms/step - accuracy: 0.7830 - loss: 0.4606 - val_accuracy: 0.8210 - val_loss: 0.4032
# Epoch 16/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - accuracy: 0.8092 - loss: 0.4206 - val_accuracy: 0.8080 - val_loss: 0.4067
# Epoch 17/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.7975 - loss: 0.4196 - val_accuracy: 0.8170 - val_loss: 0.3949
# Epoch 18/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.8084 - loss: 0.4174 - val_accuracy: 0.7770 - val_loss: 0.4426
# Epoch 20/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.8065 - loss: 0.4243 - val_accuracy: 0.8050 - val_loss: 0.4125
# Epoch 21/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 204ms/step - accuracy: 0.8296 - loss: 0.3909 - val_accuracy: 0.8260 - val_loss: 0.3654
# Epoch 22/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.8287 - loss: 0.3945 - val_accuracy: 0.8260 - val_loss: 0.4264
# Epoch 23/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 195ms/step - accuracy: 0.8127 - loss: 0.4070 - val_accuracy: 0.8190 - val_loss: 0.4075
# Epoch 24/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.8329 - loss: 0.3692 - val_accuracy: 0.8380 - val_loss: 0.3830
# Epoch 26/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 297ms/step - accuracy: 0.8258 - loss: 0.3847 - val_accuracy: 0.8510 - val_loss: 0.3606
# Epoch 27/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 258ms/step - accuracy: 0.8374 - loss: 0.3646 - val_accuracy: 0.8440 - val_loss: 0.3448
# Epoch 28/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.8430 - loss: 0.3544 - val_accuracy: 0.8070 - val_loss: 0.4345
# Epoch 29/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 189ms/step - accuracy: 0.8460 - loss: 0.3493 - val_accuracy: 0.8340 - val_loss: 0.3646
# Epoch 30/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 199ms/step - accuracy: 0.8616 - loss: 0.3424 - val_accuracy: 0.8510 - val_loss: 0.3242
# Epoch 32/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - accuracy: 0.8648 - loss: 0.3281 - val_accuracy: 0.8500 - val_loss: 0.3433
# Epoch 33/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 253ms/step - accuracy: 0.8643 - loss: 0.3231 - val_accuracy: 0.8490 - val_loss: 0.3436
# Epoch 34/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.8581 - loss: 0.3280 - val_accuracy: 0.8750 - val_loss: 0.2838
# Epoch 35/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 238ms/step - accuracy: 0.8507 - loss: 0.3367 - val_accuracy: 0.8310 - val_loss: 0.3613
# Epoch 36/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 48s 238ms/step - accuracy: 0.8645 - loss: 0.3066 - val_accuracy: 0.8510 - val_loss: 0.3948
# Epoch 38/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 253ms/step - accuracy: 0.8742 - loss: 0.3016 - val_accuracy: 0.8430 - val_loss: 0.3614
# Epoch 39/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - accuracy: 0.8868 - loss: 0.2838 - val_accuracy: 0.8630 - val_loss: 0.3164
# Epoch 40/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - accuracy: 0.8777 - loss: 0.2876 - val_accuracy: 0.8730 - val_loss: 0.3140
# Epoch 41/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 49s 243ms/step - accuracy: 0.8844 - loss: 0.2747 - val_accuracy: 0.8540 - val_loss: 0.3210
# Epoch 42/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 67us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 270ms/step - accuracy: 0.8787 - loss: 0.2739 - val_accuracy: 0.8620 - val_loss: 0.3423
# Epoch 44/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 201ms/step - accuracy: 0.8717 - loss: 0.2996 - val_accuracy: 0.8800 - val_loss: 0.2946
# Epoch 45/200
#   7/200 ━━━━━━━━━━━━━━━━━━━━ 29s 155ms/step - accuracy: 0.8864 - loss: 0.3138
